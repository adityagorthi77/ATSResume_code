# %%
pip install python-docx
# Out:
# ...
#   Using cached python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Using cached python_docx-1.1.2-py3-none-any.whl (244 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document

# Create a new Document
doc = Document()

# Add Title
doc.add_heading('SAI KRISHNA ADITYA GORTHI', level=1)
doc.add_paragraph('Analytical Professional | Aspiring Data Analyst')
doc.add_paragraph('Master of Science in Engineering Science (Data Science)')
doc.add_paragraph('+1 (716) 247-3863 | adityagorthi77@gmail.com | www.linkedin.com/in/sai-krishna-aditya-gorthi-558bb517a')

# Add Profile
doc.add_heading('PROFILE', level=2)
doc.add_paragraph(
    'Analytical and results-driven Data Analyst with proven expertise in collecting, interpreting, and transforming complex datasets into actionable insights for strategic decision-making. '
    'Skilled in managing master data processes, developing reports, and ensuring data integrity across various systems. Adept at collaborating with cross-functional teams to enhance data-driven solutions '
    'that optimize operational efficiency and meet business goals. Proficient in Power BI, Tableau, SQL, and advanced analytical techniques. Committed to delivering precise, reliable data insights and driving impactful business improvements.'
)

# Add Core Competencies
doc.add_heading('CORE COMPETENCIES', level=2)
doc.add_paragraph(
    '• Business Intelligence & Data Visualization: Power BI, Tableau, DAX formulas, LOD expressions, SQL for Business Intelligence\n'
    '• Data Management & ETL: Hadoop, Spark, Hive, Data Pipelines, Data Cleansing\n'
    '• Programming & Scripting: Python, R, SQL, MATLAB, C, C++\n'
    '• Cloud & Big Data Platforms: Azure Synapse, AWS, Impala, Azure Data Factory\n'
    '• Machine Learning & Statistical Analysis: Predictive Modeling, Neural Networks, Classification, Statistical Methods\n'
    '• Data Engineering Tools: Azure Databricks, Streamlit, Data Warehousing, SQL Server, MySQL\n'
    '• Project Management: Agile methodologies (Scrum), JIRA, Stakeholder collaboration\n'
)

# Add Experience
doc.add_heading('EXPERIENCE', level=2)

doc.add_heading('Ruffalo Noel Levitz | Engagement Ambassador', level=3)
doc.add_paragraph('Buffalo, NY | April 2023 – June 2024')
doc.add_paragraph(
    '• Collaborated with the University at Buffalo and RNL, analyzing and segmenting large alumni datasets, resulting in a 20% increase in donation participation.\n'
    '• Designed and maintained Power BI dashboards to visualize campaign KPIs and donation patterns in real-time, improving decision-making for university fundraising initiatives.\n'
    '• Created automated reports in Excel, reducing manual data entry time by 40% and enhancing accuracy.\n'
    '• Developed predictive models based on historical alumni giving data, improving engagement forecasting by 15% and enabling targeted outreach.\n'
    '• Conducted Power BI and Tableau training sessions for internal teams, enhancing the team\'s data analysis and visualization skills.\n'
    '• Presented statistical reports to senior leadership, translating data insights into strategic actions, increasing resource allocation efficiency.'
)

doc.add_heading('Tata Consultancy Services Ltd | Assistant Systems Engineer | Product Executive in TCSION Project', level=3)
doc.add_paragraph('January 2021 – January 2023')
doc.add_paragraph(
    '• Led data integration efforts for a 500,000+ dataset, ensuring data consistency, quality, and compliance, improving data reliability across departments.\n'
    '• Performed SQL analysis, streamlining ETL processes, which improved data retrieval efficiency by 40%.\n'
    '• Developed Tableau dashboards that visualized over 50 key metrics for internal clients, aiding in decision-making for network management and sales functions.\n'
    '• Worked within an Agile framework, implementing testing protocols and aligning deliverables with stakeholder needs, improving system functionality by 20%.\n'
    '• Conducted Tableau training sessions for non-technical stakeholders, ensuring they could independently navigate dashboards for actionable insights.'
)

# Add Key Projects
doc.add_heading('KEY PROJECTS', level=2)

doc.add_heading('Movie Database & Streamlit Web Application', level=3)
doc.add_paragraph(
    '• Developed a scalable movie database of 10,000+ movie records, optimizing data storage and retrieval efficiency by 35%.\n'
    '• Built an interactive Streamlit app to provide end-users with seamless access to data, improving query handling speed to under 1 second, enhancing user engagement.'
)

doc.add_heading('Sales Insights – AtliQ Hardware', level=3)
doc.add_paragraph(
    '• Designed a Power BI dashboard to analyze sales trends, identifying key metrics that guided a 7% projected revenue increase in the following quarter.\n'
    '• Presented results to sales teams, translating data insights into actionable business strategies.'
)

doc.add_heading('TalkingData Ad Tracking Fraud Detection', level=3)
doc.add_paragraph(
    '• Developed a machine learning model for ad fraud detection, achieving 98% accuracy and reducing false positives by 20%, improving detection speed.'
)

doc.add_heading('Image Colorization Using CNN', level=3)
doc.add_paragraph(
    '• Created a Convolutional Neural Network (CNN) for image colorization, achieving high-quality results using the LAB color space and transfer learning on the MIT Places dataset.'
)

doc.add_heading('Customer Churn Prediction with Artificial Neural Network (ANN)', level=3)
doc.add_paragraph(
    '• Built a customer churn prediction model using an Artificial Neural Network, analyzing 250,000+ records to aid in proactive customer retention strategies, achieving an 88% prediction accuracy rate.'
)

# Add Education
doc.add_heading('EDUCATION', level=2)

doc.add_heading('Master of Science in Engineering Science (Data Science)', level=3)
doc.add_paragraph('SUNY at Buffalo, Buffalo, NY | Expected June 2024')

doc.add_heading('Bachelor of Technology in Mechanical Engineering', level=3)
doc.add_paragraph('SASTRA University, India | April 2021')

# Add Certifications
doc.add_heading('CERTIFICATIONS', level=2)
doc.add_paragraph(
    '• Power BI: PL-300 Certification (in progress)\n'
    '• Tableau: Tableau Desktop Specialist Certification\n'
    '• Microsoft Azure for Data Engineers: DP-203\n'
    '• Data Science: IBM Data Science Professional Certification\n'
    '• Python: Introduction to Data Science Using Python – Analytics Vidhya\n'
    '• SQL: IBM Cognitive SQL Certification'
)

# Add Additional Skills
doc.add_heading('ADDITIONAL SKILLS', level=2)
doc.add_paragraph(
    '• Soft Skills: Strong communication skills for translating complex data insights into business strategies for both technical and non-technical stakeholders.\n'
    '• Tools: JIRA, Agile methodologies (Scrum), GitHub for version control, Python Libraries (Pandas, NumPy, Scikit-learn), R, MATLAB.'
)

# Save document
file_path = "//Users/saikrishnaadityagorthi/Downloads/Improved_Resume_Sai_Krishna_Aditya_Gorthi.docx"
doc.save(file_path)

file_path
# Out:
# '//Users/saikrishnaadityagorthi/Downloads/Improved_Resume_Sai_Krishna_Aditya_Gorthi.docx'
